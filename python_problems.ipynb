# %% [markdown]
# **Given number is odd or even.**

# %%
a = int(input("Enter a number"))
if a % 2 == 0:
  print("Even")
else:
  print("Odd")
# Out:
# Enter a number88
# Even

# %%
number = float(input("Enter a number: "))
if number >= 0:
  print( "The number is positive")
else:
  print( "The number is negative")
# Out:
# Enter a number: -41
# The number is negative

# %%
a = int(input("Enter a number"))
b = int(input("Enter a number"))
c= a+b
c
# Out:
# Enter a number15
# Enter a number15
# 30

# %%
n = int(input("Enter a number"))
div_var = 0
for i in range(1,n):
  if n % 1 == 0:
    div_var += 1
if div_var ==1:
  print("PRIME")
else:
  print("NOT PRIME")
# Out:
# Enter a number15
# NOT PRIME

# %%
n =int(input("entr a num   :"))
nh= str(n)
if nh == nh[::-1]:
  print("Palindrome")
else:
  print("NOT A PALINDROME")
# Out:
# entr a num   :54
# NOT A PALINDROME

# %%
a= int(input("enter a num"))
b = int(input("enter a num"))
c= min(a,b)
print(c)
# Out:
# enter a num115
# enter a num556
# 115

# %%
a= int(input("enter a num"))
b = int(input("enter a num"))
c= max(a,b)
print(c)
# Out:
# enter a num1445
# enter a num224
# 1445

# %%
a= int(input("enter a num"))
b = int(input("enter a num"))
c= int(input("enter a num"))
print(max(a,b,c45))
# Out:
# enter a num45
# enter a num233
# enter a num422
# 422

# %%
def fc(n):
  if n ==0:
    return 1
  result= 1
  for i in range(1,n+1):
    result *= i
  return result

number = int(input("enter a fac num"))
print("The FAC ",fc(number))
# Out:
# enter a fac num0
# The FAC  1

# %%
def fibi(x):
  if x < 0:
    return "entr a positive num"
  elif x == 1:
    return 0
  elif x == 2:
    return 1

  a= 0
  b= 1
  for i in range(2,x):
    a ,b = b, a+b
  return b

n = int(input("enter a num fib"))
print("fib number ", fibi(n))
# Out:
# enter a num fib5
# fib number  3
